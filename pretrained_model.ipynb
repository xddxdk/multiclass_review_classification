# %% [markdown]
# ### **1. Импорт зависимостей**
# ***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import time
import torch
import random
import datetime
import numpy as np
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import (
    accuracy_score, precision_score,
    recall_score, f1_score
    )
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import (
    TensorDataset, random_split, DataLoader,
    RandomSampler, SequentialSampler
    )
from transformers import(
    BertForSequenceClassification, AdamW,
    BertTokenizer, AutoTokenizer,
    get_linear_schedule_with_warmup
    )

# %% [markdown]
# Проверим доступность GPU

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4

# %% [markdown]
# ### **2. Загрузка данных**
# ***

# %% [markdown]
# Данные были разделены на train и test с помощью sklearn train_test_split с random_state=42.

# %%
df = pd.read_csv("drive/MyDrive/train_data.csv")

print('Number of training sentences: {:,}\n'.format(df.shape[0]))

df.sample(10)
# Out:
# Number of training sentences: 298,053
#                                                    review  \
# 66286   Очень забавляют накрученные отзывы знакомых ли...
# 166974  В Институте Мировой Экономике и Бизнеса я обуч...
# 81372   Здравствуйте, поступила на первый курс осенью ...
# 33086   Уважаемые абитуриенты, школьники и студенты! В...
# 54300   Ну такое. Много было хорошего, много было дерь...
# 152990  Я учился на медико-профилактическом факультете...
# 232665  Привет всем, кто испугался плохих и не верит х...
# 151548  Учусь в РГУТИС на 3 курсе по направлению серви...
# 254513  В СмолГУ поступил в 2017 году на иностранное о...
# 3695    Взбудораженные откровением про своих гениальны...
#
#                                            review_snippet  \
# 66286   На место них обычно берут либо людей, которые ...
# 166974  Раз в неделю студенты из других стран устраива...
# 81372   Физкультура За посещение каждого занятия даетс...
# 33086   Такие негативные социальные явления также прис...
# 54300   Вся практика была приобретена вне универа (ну ...
# 152990            Учёба сложная, особенно первые три года
# 232665  На доде всегда говорят про окна, 4 сессии в го...
# 151548  Постоянно происходят внезапные изменения в рас...
# 254513  Впечатления о ней в основном неплохие.Если анг...
# 3695     Сплошной жаргон и новояз вперемешку с матерщиной
#
#                                     category
# 66286                         Инфраструктура
# 166974    Образовательная деятельность + НИР
# 81372     Образовательная деятельность + НИР
# 33086     Образовательная деятельность + НИР
# 54300     Образовательная деятельность + НИР
# 152990    Образовательная деятельность + НИР
# 232665  Финансово-экономическая деятельность
# 151548    Образовательная деятельность + НИР
# 254513    Образовательная деятельность + НИР
# 3695           Административная деятельность

# %%
text_column = 'review_snippet'
label_column = 'category'

# %%
df[label_column].unique()
# Out:
# array(['Лояльность к ВУЗу', 'Образовательная деятельность + НИР',
#        'Финансово-экономическая деятельность',
#        'Административная деятельность', 'Внеучебная деятельность',
#        'Инфраструктура'], dtype=object)

# %%
encoder = LabelEncoder()
encoder.fit(df[label_column])
df[label_column] = encoder.transform(df[label_column])

# %%
df.head()
# Out:
#                                               review  \
# 0  На сайте МГУПП выложили еще три образовательны...
# 1  Всем привет! Отзыв о РУДН может быть либо обье...
# 2  Отличный институт,старшая ходила в ,, Ступеньк...
# 3  Ректор РНИМУ (он биохимик) первым делом разогн...
# 4  Если есть возможность, то стоит, вуз хорошо ко...
#
#                                       review_snippet  category
# 0  МГУПП, "Я тебя замучаю любовью могучею, Жаркою...         3
# 1  Он читает на бакалавриате курс «спортивная жур...         4
# 2                                       ны приемлемы         5
# 3  Ректор РНИМУ (он биохимик) первым делом разогн...         0
# 4  Если есть возможность, то стоит, вуз хорошо ко...         1

# %%
texts = df[text_column].astype(str).values
labels = df[label_column].values.astype(int)

# %%
texts[:3], labels[:3]
# Out:
# (array(['МГУПП, "Я тебя замучаю любовью могучею, Жаркою, опасною и разнообразною!" (С)',
#         'Он читает на бакалавриате курс «спортивная журналистика» (еще он читает какие-то предметы в магистратуре, но точно не могу сказать, потому что с ребятами с магистратуры мы практически не пересекаемся)',
#         'ны приемлемы'], dtype=object),
#  array([3, 4, 5]))

# %%
classes_amount = len(df[label_column].unique())
classes_amount
# Out:
# 6

# %% [markdown]
# ### **3. Токенизация и форматирование Input**
#
# В данной секции преобразуем данные к формату, с которым работает BERT.
# ***

# %% [markdown]
# ### 3.1. BERT Tokenizer

# %% [markdown]
# В ходе работы будем использовать предобученную модель архтектуры BERT на русском языке: cointegrated/rubert-tiny2

# %%
model_name = 'cointegrated/rubert-tiny2'
batch_size = 32
random_state = 42

# %%
# Load the BERT tokenizer.
print(f'Loading {model_name} tokenizer...')
tokenizer = BertTokenizer.from_pretrained(model_name)
# Out:
# Loading cointegrated/rubert-tiny2 tokenizer...

# %% [markdown]
# Применим токенайзер к одному из наших текстов и посмотрим, что получится.

# %%
# Print the original sentence.
print('Original: ', texts[0])

# Print the sentence split into tokens.
print('Tokenized: ', tokenizer.tokenize(texts[0]))

# Print the sentence mapped to token ids.
print('Token IDs: ', tokenizer.encode(texts[0]))
# Out:
# Original:  МГУПП, "Я тебя замучаю любовью могучею, Жаркою, опасною и разнообразною!" (С)
# Tokenized:  ['МГУ', '##ПП', ',', '"', 'Я', 'тебя', 'заму', '##чаю', 'любовью', 'могу', '##че', '##ю', ',', 'Жар', '##кою', ',', 'опасно', '##ю', 'и', 'разнообраз', '##ною', '!', '"', '(', 'С', ')']
# Token IDs:  [2, 21737, 36341, 16, 6, 311, 29852, 51459, 42177, 37044, 11677, 2847, 920, 16, 60919, 5636, 16, 41223, 920, 320, 30679, 5559, 5, 6, 12, 297, 13, 3]

# %% [markdown]
# ### **3.2. Токенизация данных**

# %% [markdown]
# Перед тем, как закодировать текст, найдем максимальную длину текстов.
#
#
# В ячейке ниже происходит проход по датасету для определения максимальной длины.

# %%
max_length = 0
text_lens = []

for text in texts:
  input_ids = tokenizer.encode(text, add_special_tokens=True)
  current_len = len(input_ids)
  text_lens.append(current_len)

text_lens = np.array(text_lens)
max_length = text_lens.max()
print('Max sentence length: ', max_length)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (6112 > 2048). Running this sequence through the model will result in indexing errors
# Max sentence length:  6112

# %%
# 1. Mean
mean = text_lens.mean()

# 2. Variance
variance = text_lens.var()

# 3. Standard deviation
std = text_lens.std()

# 4. Quartiles
Q1 = np.percentile(text_lens, 25)
Q2 = np.percentile(text_lens, 50)
Q3 = np.percentile(text_lens, 75)

# Print results
print("Mean:", mean)
print("Median:", Q2)
print("Variance:", variance)
print("Standard deviation:", std)
print(f"Q1 = {Q1}, Q3 = {Q3}")
# Out:
# Mean: 25.048702747497927
# Median: 20.0
# Variance: 4761.615810043571
# Standard deviation: 69.00446224733275
# Q1 = 13.0, Q3 = 30.0

# %% [markdown]
# За длину возьмем 3 квартиль

# %%
max_length = int(Q3)

# %% [markdown]
# Формируем токенизированные множества.

# %%
# Tokenize all of the sentences and map the tokens to thier word IDs.
def preparing_text_and_labels(texts, labels, max_length, truncation=False):
    input_ids = []
    attention_masks = []

    for text in texts:

        encoded_dict = tokenizer.encode_plus(
                            text,
                            add_special_tokens = True,
                            max_length = max_length,
                            padding='max_length',
                            return_attention_mask = True,
                            return_tensors = 'pt',
                            truncation=truncation
                    )

        # Add the encoded sentence to the list.
        input_ids.append(encoded_dict['input_ids'])

        # And its attention mask (simply differentiates padding from non-padding).
        attention_masks.append(encoded_dict['attention_mask'])

    # Convert the lists into tensors.
    input_ids = torch.cat(input_ids, dim=0)
    attention_masks = torch.cat(attention_masks, dim=0)
    labels = torch.tensor(labels)
    return input_ids, attention_masks, labels

# %%
input_ids, attention_masks, labels = preparing_text_and_labels(texts, labels, max_length=max_length, truncation=True)

print('Original: ', texts[0])
print('Token IDs:', input_ids[0])
# Out:
# Original:  МГУПП, "Я тебя замучаю любовью могучею, Жаркою, опасною и разнообразною!" (С)
# Token IDs: tensor([    2, 21737, 36341,    16,     6,   311, 29852, 51459, 42177, 37044,
#         11677,  2847,   920,    16, 60919,  5636,    16, 41223,   920,   320,
#         30679,  5559,     5,     6,    12,   297,    13,     3,     0,     0])

# %% [markdown]
# ### **3.3. Разбиение на train и val**

# %% [markdown]
# Разделим данные на train и val в пропорции  90% к 10%.

# %%
train_part = 0.9

# %%
# Combine the training inputs into a TensorDataset.
dataset = TensorDataset(input_ids, attention_masks, labels)

# Calculate the number of samples to include in each set.
train_size = int(train_part * len(dataset))
val_size = len(dataset) - train_size

# Divide the dataset by randomly selecting samples.
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

print('{:>5,} training samples'.format(train_size))
print('{:>5,} validation samples'.format(val_size))
# Out:
# 268,247 training samples
# 29,806 validation samples

# %% [markdown]
# Также создадим итератор с использование класса  DataLoader из библиотеки torch.

# %%
train_dataloader = DataLoader(
            train_dataset,
            sampler = RandomSampler(train_dataset), # Select batches randomly
            batch_size = batch_size
        )

validation_dataloader = DataLoader(
            val_dataset,
            sampler = SequentialSampler(val_dataset), # Pull out batches sequentially.
            batch_size = batch_size
        )

# %% [markdown]
# Теперь, когда данные отформатированы, можем обучить модель.

# %% [markdown]
# ### **4. Обучение**
# ***
# ### 4.1. BertForSequenceClassification

# %%
model = BertForSequenceClassification.from_pretrained(
    model_name,
    num_labels = classes_amount, # The number of output labels--2 for binary classification.
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False, # Whether the model returns all hidden-states.
)

# Using GPU.
model.cuda()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cointegrated/rubert-tiny2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(83828, 312, padding_idx=0)
#       (position_embeddings): Embedding(2048, 312)
#       (token_type_embeddings): Embedding(2, 312)
#       (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-2): 3 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=312, out_features=312, bias=True)
#               (key): Linear(in_features=312, out_features=312, bias=True)
#               (value): Linear(in_features=312, out_features=312, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=312, out_features=312, bias=True)
#               (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=312, out_features=600, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=600, out_features=312, bias=True)
#             (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=312, out_features=312, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=312, out_features=6, bias=True)
# )

# %% [markdown]
# Ради интереса выведем на печать параметры для нескольких слоев:
#
#
# 1. The embedding layer.
# 2. Первый из 12 ти трансформеров.
# 3. The output layer.

# %%
# Get all of the model's parameters as a list of tuples.
params = list(model.named_parameters())

print('The BERT model has {:} different named parameters.\n'.format(len(params)))

print('==== Embedding Layer ====\n')

for p in params[0:5]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))

print('\n==== First Transformer ====\n')

for p in params[5:21]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))

print('\n==== Output Layer ====\n')

for p in params[-4:]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))
# Out:
# The BERT model has 57 different named parameters.
#
# ==== Embedding Layer ====
#
# bert.embeddings.word_embeddings.weight                  (83828, 312)
# bert.embeddings.position_embeddings.weight               (2048, 312)
# bert.embeddings.token_type_embeddings.weight                (2, 312)
# bert.embeddings.LayerNorm.weight                              (312,)
# bert.embeddings.LayerNorm.bias                                (312,)
#
# ==== First Transformer ====
#
# bert.encoder.layer.0.attention.self.query.weight          (312, 312)
# bert.encoder.layer.0.attention.self.query.bias                (312,)
# bert.encoder.layer.0.attention.self.key.weight            (312, 312)
# bert.encoder.layer.0.attention.self.key.bias                  (312,)
# bert.encoder.layer.0.attention.self.value.weight          (312, 312)
# bert.encoder.layer.0.attention.self.value.bias                (312,)
# bert.encoder.layer.0.attention.output.dense.weight        (312, 312)
# bert.encoder.layer.0.attention.output.dense.bias              (312,)
# bert.encoder.layer.0.attention.output.LayerNorm.weight        (312,)
# bert.encoder.layer.0.attention.output.LayerNorm.bias          (312,)
# bert.encoder.layer.0.intermediate.dense.weight            (600, 312)
# bert.encoder.layer.0.intermediate.dense.bias                  (600,)
# bert.encoder.layer.0.output.dense.weight                  (312, 600)
# bert.encoder.layer.0.output.dense.bias                        (312,)
# bert.encoder.layer.0.output.LayerNorm.weight                  (312,)
# bert.encoder.layer.0.output.LayerNorm.bias                    (312,)
#
# ==== Output Layer ====
#
# bert.pooler.dense.weight                                  (312, 312)
# bert.pooler.dense.bias                                        (312,)
# classifier.weight                                           (6, 312)
# classifier.bias                                                 (6,)

# %% [markdown]
# ### **4.2. Оптимизация**

# %% [markdown]
# Определим optimizer и sheduler.
#
# Наиболее популярные конфигурации параметров:
# - **Batch size:** 16, 32
# - **Learning rate (Adam):** 5e-5, 3e-5, 2e-5
# - **Number of epochs:** 2, 3, 4
#
# Мы выберем:
# * Batch size: 32 (при инициализации DataLoaders)
# * Learning rate: 2e-5
# * Epochs: 4
#
# Параметр эпсилон `eps = 1e-8` - это "очень маленькое число", которое позволяет избежать деления на 0

# %%
optimizer = AdamW(model.parameters(),
                  lr = 2e-5,
                  eps = 1e-8
                )
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
epochs = 4

total_steps = len(train_dataloader) * epochs

# Create the learning rate scheduler.
scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)

# %% [markdown]
# ### **4.3. Петля обучения**

# %% [markdown]
# Ниже приведена петля обучения (training loop). На каждом проходе по данным мы проходим по всему обучающему и валидационную датасетам.
#
#
# **Training:**
# - Распаковать обучающие данные и лейблы
# - Загрузить данные на GPU для ускорения
# - Занулить градиенты с предыдущего шаге
# - Forward pass (скормить данные в нейросеть и пробросить их вперед)
# - Backward pass (backpropagation - посчитать градиенты по всем параметрам с помощью обратного распространения ошибки)
# - Обновить параметры с помощью optimizer.step()
# - Посчитать статистики, чтобы следить за обучением
#
# **Evalution:**
# - Распаковать валидационные данные и лейблы
# - Загрузить данные на GPU для ускорения
# - Forward pass (скормить данные в нейросеть и пробросить их вперед)
# - Посчитать loss и статистики на валидационных данных, чтобы следить за обучением

# %% [markdown]
# ##

# %% [markdown]
# Вспомогательная функция для вычисления F1.

# %%
# Function to calculate the f1 of our predictions vs labels
def flat_f1(preds, labels, average):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(pred_flat, labels_flat, average=average)

# %% [markdown]
# Вспомогательная функция для отслеживания затраченного времени.

# %%
def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))

    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %% [markdown]
# Все готово к обучению! Приступим!

# %%
def fine_tune_model(train_dataloader, validation_dataloader,  average, random_state=random_state):

    random.seed(random_state)
    np.random.seed(random_state)
    torch.manual_seed(random_state)
    torch.cuda.manual_seed_all(random_state)

    training_stats = []

    # Measure the total training time for the whole run.
    total_t0 = time.time()

    # For each epoch...
    for epoch_i in range(0, epochs):

        print("")
        print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
        print('Training...')

        # Measure how long the training epoch takes.
        t0 = time.time()

        # Reset the total loss for this epoch.
        total_train_loss = 0

        model.train()

        # For each batch of training data...
        for step, batch in enumerate(train_dataloader):

            # Progress update every 40 batches.
            if step % 40 == 0 and not step == 0:
                # Calculate elapsed time in minutes.
                elapsed = format_time(time.time() - t0)

                # Report progress.
                print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

            b_input_ids = batch[0].to(device)
            b_input_mask = batch[1].to(device)
            b_labels = batch[2].to(device)

            model.zero_grad()

            res = model(b_input_ids,
                                token_type_ids=None,
                                attention_mask=b_input_mask,
                                labels=b_labels)
            loss = res['loss']
            logits = res['logits']

            total_train_loss += loss.item()

            # Perform a backward pass to calculate the gradients.
            loss.backward()

            # This is to help prevent the "exploding gradients" problem.
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

            optimizer.step()

            # Update the learning rate.
            scheduler.step()

        # Calculate the average loss over all of the batches.
        avg_train_loss = total_train_loss / len(train_dataloader)

        # Measure how long this epoch took.
        training_time = format_time(time.time() - t0)

        print("")
        print("  Average training loss: {0:.2f}".format(avg_train_loss))
        print("  Training epcoh took: {:}".format(training_time))

        # Validation
        print("")
        print("Running Validation...")

        t0 = time.time()

        # Put the model in evaluation mode--the dropout layers behave differently
        # during evaluation.
        model.eval()

        # Tracking variables
        total_eval_f1 = 0
        total_eval_loss = 0
        nb_eval_steps = 0

        # Evaluate data for one epoch
        for batch in validation_dataloader:

            b_input_ids = batch[0].to(device)
            b_input_mask = batch[1].to(device)
            b_labels = batch[2].to(device)

            with torch.no_grad():

                res = model(b_input_ids,
                                    token_type_ids=None,
                                    attention_mask=b_input_mask,
                                    labels=b_labels)
                loss = res['loss']
                logits = res['logits']

            # Accumulate the validation loss.
            total_eval_loss += loss.item()

            # Move logits and labels to CPU
            logits = logits.detach().cpu().numpy()
            label_ids = b_labels.to('cpu').numpy()

            # Calculate the accuracy for this batch of test sentences, and
            # accumulate it over all batches.
            total_eval_f1 += flat_f1(logits, label_ids, average)


        # Report the final accuracy for this validation run.
        avg_val_f1 = total_eval_f1 / len(validation_dataloader)
        print("  F1: {0:.2f}".format(avg_val_f1))

        # Calculate the average loss over all of the batches.
        avg_val_loss = total_eval_loss / len(validation_dataloader)

        # Measure how long the validation run took.
        validation_time = format_time(time.time() - t0)

        print("  Validation Loss: {0:.2f}".format(avg_val_loss))
        print("  Validation took: {:}".format(validation_time))

        # Record all statistics from this epoch.
        training_stats.append(
            {
                'epoch': epoch_i + 1,
                'Training Loss': avg_train_loss,
                'Valid. Loss': avg_val_loss,
                'Valid. F1.': avg_val_f1,
                'Training Time': training_time,
                'Validation Time': validation_time
            }
        )

    print("")

    print("Training complete!")

    print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
    return training_stats

# %%
training_stats = fine_tune_model(train_dataloader, validation_dataloader, average='macro')
# Out:
# ======== Epoch 1 / 4 ========
# Training...
#   Batch    40  of  8,383.    Elapsed: 0:00:01.
#   Batch    80  of  8,383.    Elapsed: 0:00:02.
#   Batch   120  of  8,383.    Elapsed: 0:00:02.
#   Batch   160  of  8,383.    Elapsed: 0:00:03.
#   Batch   200  of  8,383.    Elapsed: 0:00:04.
#   Batch   240  of  8,383.    Elapsed: 0:00:05.
#   Batch   280  of  8,383.    Elapsed: 0:00:06.
#   Batch   320  of  8,383.    Elapsed: 0:00:06.
#   Batch   360  of  8,383.    Elapsed: 0:00:07.
#   Batch   400  of  8,383.    Elapsed: 0:00:08.
#   Batch   440  of  8,383.    Elapsed: 0:00:09.
#   Batch   480  of  8,383.    Elapsed: 0:00:10.
#   Batch   520  of  8,383.    Elapsed: 0:00:11.
#   Batch   560  of  8,383.    Elapsed: 0:00:12.
#   Batch   600  of  8,383.    Elapsed: 0:00:12.
#   Batch   640  of  8,383.    Elapsed: 0:00:13.
#   Batch   680  of  8,383.    Elapsed: 0:00:14.
#   Batch   720  of  8,383.    Elapsed: 0:00:15.
#   Batch   760  of  8,383.    Elapsed: 0:00:16.
#   Batch   800  of  8,383.    Elapsed: 0:00:17.
#   Batch   840  of  8,383.    Elapsed: 0:00:17.
#   Batch   880  of  8,383.    Elapsed: 0:00:18.
#   Batch   920  of  8,383.    Elapsed: 0:00:19.
#   Batch   960  of  8,383.    Elapsed: 0:00:20.
#   Batch 1,000  of  8,383.    Elapsed: 0:00:21.
#   Batch 1,040  of  8,383.    Elapsed: 0:00:21.
#   Batch 1,080  of  8,383.    Elapsed: 0:00:22.
#   Batch 1,120  of  8,383.    Elapsed: 0:00:23.
#   Batch 1,160  of  8,383.    Elapsed: 0:00:24.
#   Batch 1,200  of  8,383.    Elapsed: 0:00:25.
#   Batch 1,240  of  8,383.    Elapsed: 0:00:26.
#   Batch 1,280  of  8,383.    Elapsed: 0:00:26.
#   Batch 1,320  of  8,383.    Elapsed: 0:00:27.
#   Batch 1,360  of  8,383.    Elapsed: 0:00:28.
#   Batch 1,400  of  8,383.    Elapsed: 0:00:29.
#   Batch 1,440  of  8,383.    Elapsed: 0:00:30.
#   Batch 1,480  of  8,383.    Elapsed: 0:00:30.
#   Batch 1,520  of  8,383.    Elapsed: 0:00:31.
#   Batch 1,560  of  8,383.    Elapsed: 0:00:32.
#   Batch 1,600  of  8,383.    Elapsed: 0:00:33.
#   Batch 1,640  of  8,383.    Elapsed: 0:00:34.
#   Batch 1,680  of  8,383.    Elapsed: 0:00:35.
#   Batch 1,720  of  8,383.    Elapsed: 0:00:35.
#   Batch 1,760  of  8,383.    Elapsed: 0:00:36.
#   Batch 1,800  of  8,383.    Elapsed: 0:00:37.
#   Batch 1,840  of  8,383.    Elapsed: 0:00:38.
#   Batch 1,880  of  8,383.    Elapsed: 0:00:39.
#   Batch 1,920  of  8,383.    Elapsed: 0:00:40.
#   Batch 1,960  of  8,383.    Elapsed: 0:00:40.
#   Batch 2,000  of  8,383.    Elapsed: 0:00:41.
#   Batch 2,040  of  8,383.    Elapsed: 0:00:42.
#   Batch 2,080  of  8,383.    Elapsed: 0:00:43.
#   Batch 2,120  of  8,383.    Elapsed: 0:00:44.
#   Batch 2,160  of  8,383.    Elapsed: 0:00:44.
#   Batch 2,200  of  8,383.    Elapsed: 0:00:45.
#   Batch 2,240  of  8,383.    Elapsed: 0:00:46.
#   Batch 2,280  of  8,383.    Elapsed: 0:00:47.
#   Batch 2,320  of  8,383.    Elapsed: 0:00:48.
#   Batch 2,360  of  8,383.    Elapsed: 0:00:49.
#   Batch 2,400  of  8,383.    Elapsed: 0:00:49.
#   Batch 2,440  of  8,383.    Elapsed: 0:00:50.
#   Batch 2,480  of  8,383.    Elapsed: 0:00:51.
#   Batch 2,520  of  8,383.    Elapsed: 0:00:52.
#   Batch 2,560  of  8,383.    Elapsed: 0:00:53.
#   Batch 2,600  of  8,383.    Elapsed: 0:00:54.
#   Batch 2,640  of  8,383.    Elapsed: 0:00:54.
#   Batch 2,680  of  8,383.    Elapsed: 0:00:55.
#   Batch 2,720  of  8,383.    Elapsed: 0:00:56.
#   Batch 2,760  of  8,383.    Elapsed: 0:00:57.
#   Batch 2,800  of  8,383.    Elapsed: 0:00:58.
#   Batch 2,840  of  8,383.    Elapsed: 0:00:58.
#   Batch 2,880  of  8,383.    Elapsed: 0:00:59.
#   Batch 2,920  of  8,383.    Elapsed: 0:01:00.
#   Batch 2,960  of  8,383.    Elapsed: 0:01:01.
#   Batch 3,000  of  8,383.    Elapsed: 0:01:02.
#   Batch 3,040  of  8,383.    Elapsed: 0:01:03.
#   Batch 3,080  of  8,383.    Elapsed: 0:01:03.
#   Batch 3,120  of  8,383.    Elapsed: 0:01:04.
#   Batch 3,160  of  8,383.    Elapsed: 0:01:05.
#   Batch 3,200  of  8,383.    Elapsed: 0:01:06.
#   Batch 3,240  of  8,383.    Elapsed: 0:01:07.
#   Batch 3,280  of  8,383.    Elapsed: 0:01:07.
#   Batch 3,320  of  8,383.    Elapsed: 0:01:08.
#   Batch 3,360  of  8,383.    Elapsed: 0:01:09.
#   Batch 3,400  of  8,383.    Elapsed: 0:01:10.
#   Batch 3,440  of  8,383.    Elapsed: 0:01:11.
#   Batch 3,480  of  8,383.    Elapsed: 0:01:11.
#   Batch 3,520  of  8,383.    Elapsed: 0:01:12.
#   Batch 3,560  of  8,383.    Elapsed: 0:01:13.
#   Batch 3,600  of  8,383.    Elapsed: 0:01:14.
#   Batch 3,640  of  8,383.    Elapsed: 0:01:15.
#   Batch 3,680  of  8,383.    Elapsed: 0:01:16.
#   Batch 3,720  of  8,383.    Elapsed: 0:01:16.
#   Batch 3,760  of  8,383.    Elapsed: 0:01:17.
#   Batch 3,800  of  8,383.    Elapsed: 0:01:18.
#   Batch 3,840  of  8,383.    Elapsed: 0:01:19.
#   Batch 3,880  of  8,383.    Elapsed: 0:01:20.
#   Batch 3,920  of  8,383.    Elapsed: 0:01:21.
#   Batch 3,960  of  8,383.    Elapsed: 0:01:21.
#   Batch 4,000  of  8,383.    Elapsed: 0:01:22.
#   Batch 4,040  of  8,383.    Elapsed: 0:01:23.
#   Batch 4,080  of  8,383.    Elapsed: 0:01:24.
#   Batch 4,120  of  8,383.    Elapsed: 0:01:25.
#   Batch 4,160  of  8,383.    Elapsed: 0:01:25.
#   Batch 4,200  of  8,383.    Elapsed: 0:01:26.
#   Batch 4,240  of  8,383.    Elapsed: 0:01:27.
#   Batch 4,280  of  8,383.    Elapsed: 0:01:28.
#   Batch 4,320  of  8,383.    Elapsed: 0:01:29.
#   Batch 4,360  of  8,383.    Elapsed: 0:01:30.
#   Batch 4,400  of  8,383.    Elapsed: 0:01:30.
#   Batch 4,440  of  8,383.    Elapsed: 0:01:31.
#   Batch 4,480  of  8,383.    Elapsed: 0:01:32.
#   Batch 4,520  of  8,383.    Elapsed: 0:01:33.
#   Batch 4,560  of  8,383.    Elapsed: 0:01:34.
#   Batch 4,600  of  8,383.    Elapsed: 0:01:35.
#   Batch 4,640  of  8,383.    Elapsed: 0:01:35.
#   Batch 4,680  of  8,383.    Elapsed: 0:01:36.
#   Batch 4,720  of  8,383.    Elapsed: 0:01:37.
#   Batch 4,760  of  8,383.    Elapsed: 0:01:38.
#   Batch 4,800  of  8,383.    Elapsed: 0:01:39.
#   Batch 4,840  of  8,383.    Elapsed: 0:01:39.
#   Batch 4,880  of  8,383.    Elapsed: 0:01:40.
#   Batch 4,920  of  8,383.    Elapsed: 0:01:41.
#   Batch 4,960  of  8,383.    Elapsed: 0:01:42.
#   Batch 5,000  of  8,383.    Elapsed: 0:01:43.
#   Batch 5,040  of  8,383.    Elapsed: 0:01:44.
#   Batch 5,080  of  8,383.    Elapsed: 0:01:44.
#   Batch 5,120  of  8,383.    Elapsed: 0:01:45.
#   Batch 5,160  of  8,383.    Elapsed: 0:01:46.
#   Batch 5,200  of  8,383.    Elapsed: 0:01:47.
#   Batch 5,240  of  8,383.    Elapsed: 0:01:48.
#   Batch 5,280  of  8,383.    Elapsed: 0:01:49.
#   Batch 5,320  of  8,383.    Elapsed: 0:01:49.
#   Batch 5,360  of  8,383.    Elapsed: 0:01:50.
#   Batch 5,400  of  8,383.    Elapsed: 0:01:51.
#   Batch 5,440  of  8,383.    Elapsed: 0:01:52.
#   Batch 5,480  of  8,383.    Elapsed: 0:01:53.
#   Batch 5,520  of  8,383.    Elapsed: 0:01:53.
#   Batch 5,560  of  8,383.    Elapsed: 0:01:54.
#   Batch 5,600  of  8,383.    Elapsed: 0:01:55.
#   Batch 5,640  of  8,383.    Elapsed: 0:01:56.
#   Batch 5,680  of  8,383.    Elapsed: 0:01:57.
#   Batch 5,720  of  8,383.    Elapsed: 0:01:58.
#   Batch 5,760  of  8,383.    Elapsed: 0:01:58.
#   Batch 5,800  of  8,383.    Elapsed: 0:01:59.
#   Batch 5,840  of  8,383.    Elapsed: 0:02:00.
#   Batch 5,880  of  8,383.    Elapsed: 0:02:01.
#   Batch 5,920  of  8,383.    Elapsed: 0:02:02.
#   Batch 5,960  of  8,383.    Elapsed: 0:02:03.
#   Batch 6,000  of  8,383.    Elapsed: 0:02:03.
#   Batch 6,040  of  8,383.    Elapsed: 0:02:04.
#   Batch 6,080  of  8,383.    Elapsed: 0:02:05.
#   Batch 6,120  of  8,383.    Elapsed: 0:02:06.
#   Batch 6,160  of  8,383.    Elapsed: 0:02:07.
#   Batch 6,200  of  8,383.    Elapsed: 0:02:07.
#   Batch 6,240  of  8,383.    Elapsed: 0:02:08.
#   Batch 6,280  of  8,383.    Elapsed: 0:02:09.
#   Batch 6,320  of  8,383.    Elapsed: 0:02:10.
#   Batch 6,360  of  8,383.    Elapsed: 0:02:11.
#   Batch 6,400  of  8,383.    Elapsed: 0:02:12.
#   Batch 6,440  of  8,383.    Elapsed: 0:02:12.
#   Batch 6,480  of  8,383.    Elapsed: 0:02:13.
#   Batch 6,520  of  8,383.    Elapsed: 0:02:14.
#   Batch 6,560  of  8,383.    Elapsed: 0:02:15.
#   Batch 6,600  of  8,383.    Elapsed: 0:02:16.
#   Batch 6,640  of  8,383.    Elapsed: 0:02:16.
#   Batch 6,680  of  8,383.    Elapsed: 0:02:17.
#   Batch 6,720  of  8,383.    Elapsed: 0:02:18.
#   Batch 6,760  of  8,383.    Elapsed: 0:02:19.
#   Batch 6,800  of  8,383.    Elapsed: 0:02:20.
#   Batch 6,840  of  8,383.    Elapsed: 0:02:20.
#   Batch 6,880  of  8,383.    Elapsed: 0:02:21.
#   Batch 6,920  of  8,383.    Elapsed: 0:02:22.
#   Batch 6,960  of  8,383.    Elapsed: 0:02:23.
#   Batch 7,000  of  8,383.    Elapsed: 0:02:24.
#   Batch 7,040  of  8,383.    Elapsed: 0:02:25.
#   Batch 7,080  of  8,383.    Elapsed: 0:02:26.
#   Batch 7,120  of  8,383.    Elapsed: 0:02:26.
#   Batch 7,160  of  8,383.    Elapsed: 0:02:27.
#   Batch 7,200  of  8,383.    Elapsed: 0:02:28.
#   Batch 7,240  of  8,383.    Elapsed: 0:02:29.
#   Batch 7,280  of  8,383.    Elapsed: 0:02:30.
#   Batch 7,320  of  8,383.    Elapsed: 0:02:30.
#   Batch 7,360  of  8,383.    Elapsed: 0:02:31.
#   Batch 7,400  of  8,383.    Elapsed: 0:02:32.
#   Batch 7,440  of  8,383.    Elapsed: 0:02:33.
#   Batch 7,480  of  8,383.    Elapsed: 0:02:34.
#   Batch 7,520  of  8,383.    Elapsed: 0:02:34.
#   Batch 7,560  of  8,383.    Elapsed: 0:02:35.
#   Batch 7,600  of  8,383.    Elapsed: 0:02:36.
#   Batch 7,640  of  8,383.    Elapsed: 0:02:37.
#   Batch 7,680  of  8,383.    Elapsed: 0:02:38.
#   Batch 7,720  of  8,383.    Elapsed: 0:02:39.
#   Batch 7,760  of  8,383.    Elapsed: 0:02:40.
#   Batch 7,800  of  8,383.    Elapsed: 0:02:40.
#   Batch 7,840  of  8,383.    Elapsed: 0:02:41.
#   Batch 7,880  of  8,383.    Elapsed: 0:02:42.
#   Batch 7,920  of  8,383.    Elapsed: 0:02:43.
#   Batch 7,960  of  8,383.    Elapsed: 0:02:44.
#   Batch 8,000  of  8,383.    Elapsed: 0:02:44.
#   Batch 8,040  of  8,383.    Elapsed: 0:02:45.
#   Batch 8,080  of  8,383.    Elapsed: 0:02:46.
#   Batch 8,120  of  8,383.    Elapsed: 0:02:47.
#   Batch 8,160  of  8,383.    Elapsed: 0:02:48.
#   Batch 8,200  of  8,383.    Elapsed: 0:02:48.
#   Batch 8,240  of  8,383.    Elapsed: 0:02:49.
#   Batch 8,280  of  8,383.    Elapsed: 0:02:50.
#   Batch 8,320  of  8,383.    Elapsed: 0:02:51.
#   Batch 8,360  of  8,383.    Elapsed: 0:02:52.
#
#   Average training loss: 0.55
#   Training epcoh took: 0:02:52
#
# Running Validation...
#   F1: 0.75
#   Validation Loss: 0.43
#   Validation took: 0:00:05
#
# ======== Epoch 2 / 4 ========
# Training...
#   Batch    40  of  8,383.    Elapsed: 0:00:01.
#   Batch    80  of  8,383.    Elapsed: 0:00:02.
#   Batch   120  of  8,383.    Elapsed: 0:00:02.
#   Batch   160  of  8,383.    Elapsed: 0:00:03.
#   Batch   200  of  8,383.    Elapsed: 0:00:04.
#   Batch   240  of  8,383.    Elapsed: 0:00:05.
#   Batch   280  of  8,383.    Elapsed: 0:00:06.
#   Batch   320  of  8,383.    Elapsed: 0:00:07.
#   Batch   360  of  8,383.    Elapsed: 0:00:07.
#   Batch   400  of  8,383.    Elapsed: 0:00:08.
#   Batch   440  of  8,383.    Elapsed: 0:00:09.
#   Batch   480  of  8,383.    Elapsed: 0:00:10.
#   Batch   520  of  8,383.    Elapsed: 0:00:11.
#   Batch   560  of  8,383.    Elapsed: 0:00:12.
#   Batch   600  of  8,383.    Elapsed: 0:00:12.
#   Batch   640  of  8,383.    Elapsed: 0:00:13.
#   Batch   680  of  8,383.    Elapsed: 0:00:14.
#   Batch   720  of  8,383.    Elapsed: 0:00:15.
#   Batch   760  of  8,383.    Elapsed: 0:00:16.
#   Batch   800  of  8,383.    Elapsed: 0:00:16.
#   Batch   840  of  8,383.    Elapsed: 0:00:17.
#   Batch   880  of  8,383.    Elapsed: 0:00:18.
#   Batch   920  of  8,383.    Elapsed: 0:00:19.
#   Batch   960  of  8,383.    Elapsed: 0:00:20.
#   Batch 1,000  of  8,383.    Elapsed: 0:00:21.
#   Batch 1,040  of  8,383.    Elapsed: 0:00:21.
#   Batch 1,080  of  8,383.    Elapsed: 0:00:22.
#   Batch 1,120  of  8,383.    Elapsed: 0:00:23.
#   Batch 1,160  of  8,383.    Elapsed: 0:00:24.
#   Batch 1,200  of  8,383.    Elapsed: 0:00:25.
#   Batch 1,240  of  8,383.    Elapsed: 0:00:26.
#   Batch 1,280  of  8,383.    Elapsed: 0:00:26.
#   Batch 1,320  of  8,383.    Elapsed: 0:00:27.
#   Batch 1,360  of  8,383.    Elapsed: 0:00:28.
#   Batch 1,400  of  8,383.    Elapsed: 0:00:29.
#   Batch 1,440  of  8,383.    Elapsed: 0:00:30.
#   Batch 1,480  of  8,383.    Elapsed: 0:00:30.
#   Batch 1,520  of  8,383.    Elapsed: 0:00:31.
#   Batch 1,560  of  8,383.    Elapsed: 0:00:32.
#   Batch 1,600  of  8,383.    Elapsed: 0:00:33.
#   Batch 1,640  of  8,383.    Elapsed: 0:00:34.
#   Batch 1,680  of  8,383.    Elapsed: 0:00:35.
#   Batch 1,720  of  8,383.    Elapsed: 0:00:35.
#   Batch 1,760  of  8,383.    Elapsed: 0:00:36.
#   Batch 1,800  of  8,383.    Elapsed: 0:00:37.
#   Batch 1,840  of  8,383.    Elapsed: 0:00:38.
#   Batch 1,880  of  8,383.    Elapsed: 0:00:39.
#   Batch 1,920  of  8,383.    Elapsed: 0:00:39.
#   Batch 1,960  of  8,383.    Elapsed: 0:00:40.
#   Batch 2,000  of  8,383.    Elapsed: 0:00:41.
#   Batch 2,040  of  8,383.    Elapsed: 0:00:42.
#   Batch 2,080  of  8,383.    Elapsed: 0:00:43.
#   Batch 2,120  of  8,383.    Elapsed: 0:00:43.
#   Batch 2,160  of  8,383.    Elapsed: 0:00:44.
#   Batch 2,200  of  8,383.    Elapsed: 0:00:45.
#   Batch 2,240  of  8,383.    Elapsed: 0:00:46.
#   Batch 2,280  of  8,383.    Elapsed: 0:00:47.
#   Batch 2,320  of  8,383.    Elapsed: 0:00:48.
#   Batch 2,360  of  8,383.    Elapsed: 0:00:49.
#   Batch 2,400  of  8,383.    Elapsed: 0:00:49.
#   Batch 2,440  of  8,383.    Elapsed: 0:00:50.
#   Batch 2,480  of  8,383.    Elapsed: 0:00:51.
#   Batch 2,520  of  8,383.    Elapsed: 0:00:52.
#   Batch 2,560  of  8,383.    Elapsed: 0:00:53.
#   Batch 2,600  of  8,383.    Elapsed: 0:00:53.
#   Batch 2,640  of  8,383.    Elapsed: 0:00:54.
#   Batch 2,680  of  8,383.    Elapsed: 0:00:55.
#   Batch 2,720  of  8,383.    Elapsed: 0:00:56.
#   Batch 2,760  of  8,383.    Elapsed: 0:00:57.
#   Batch 2,800  of  8,383.    Elapsed: 0:00:58.
#   Batch 2,840  of  8,383.    Elapsed: 0:00:58.
#   Batch 2,880  of  8,383.    Elapsed: 0:00:59.
#   Batch 2,920  of  8,383.    Elapsed: 0:01:00.
#   Batch 2,960  of  8,383.    Elapsed: 0:01:01.
#   Batch 3,000  of  8,383.    Elapsed: 0:01:02.
#   Batch 3,040  of  8,383.    Elapsed: 0:01:03.
#   Batch 3,080  of  8,383.    Elapsed: 0:01:03.
#   Batch 3,120  of  8,383.    Elapsed: 0:01:04.
#   Batch 3,160  of  8,383.    Elapsed: 0:01:05.
#   Batch 3,200  of  8,383.    Elapsed: 0:01:06.
#   Batch 3,240  of  8,383.    Elapsed: 0:01:07.
#   Batch 3,280  of  8,383.    Elapsed: 0:01:08.
#   Batch 3,320  of  8,383.    Elapsed: 0:01:08.
#   Batch 3,360  of  8,383.    Elapsed: 0:01:09.
#   Batch 3,400  of  8,383.    Elapsed: 0:01:10.
#   Batch 3,440  of  8,383.    Elapsed: 0:01:11.
#   Batch 3,480  of  8,383.    Elapsed: 0:01:12.
#   Batch 3,520  of  8,383.    Elapsed: 0:01:12.
#   Batch 3,560  of  8,383.    Elapsed: 0:01:13.
#   Batch 3,600  of  8,383.    Elapsed: 0:01:14.
#   Batch 3,640  of  8,383.    Elapsed: 0:01:15.
#   Batch 3,680  of  8,383.    Elapsed: 0:01:16.
#   Batch 3,720  of  8,383.    Elapsed: 0:01:17.
#   Batch 3,760  of  8,383.    Elapsed: 0:01:17.
#   Batch 3,800  of  8,383.    Elapsed: 0:01:18.
#   Batch 3,840  of  8,383.    Elapsed: 0:01:19.
#   Batch 3,880  of  8,383.    Elapsed: 0:01:20.
#   Batch 3,920  of  8,383.    Elapsed: 0:01:21.
#   Batch 3,960  of  8,383.    Elapsed: 0:01:22.
#   Batch 4,000  of  8,383.    Elapsed: 0:01:22.
#   Batch 4,040  of  8,383.    Elapsed: 0:01:23.
#   Batch 4,080  of  8,383.    Elapsed: 0:01:24.
#   Batch 4,120  of  8,383.    Elapsed: 0:01:25.
#   Batch 4,160  of  8,383.    Elapsed: 0:01:26.
#   Batch 4,200  of  8,383.    Elapsed: 0:01:26.
#   Batch 4,240  of  8,383.    Elapsed: 0:01:27.
#   Batch 4,280  of  8,383.    Elapsed: 0:01:28.
#   Batch 4,320  of  8,383.    Elapsed: 0:01:29.
#   Batch 4,360  of  8,383.    Elapsed: 0:01:30.
#   Batch 4,400  of  8,383.    Elapsed: 0:01:31.
#   Batch 4,440  of  8,383.    Elapsed: 0:01:32.
#   Batch 4,480  of  8,383.    Elapsed: 0:01:32.
#   Batch 4,520  of  8,383.    Elapsed: 0:01:33.
#   Batch 4,560  of  8,383.    Elapsed: 0:01:34.
#   Batch 4,600  of  8,383.    Elapsed: 0:01:35.
#   Batch 4,640  of  8,383.    Elapsed: 0:01:36.
#   Batch 4,680  of  8,383.    Elapsed: 0:01:36.
#   Batch 4,720  of  8,383.    Elapsed: 0:01:37.
#   Batch 4,760  of  8,383.    Elapsed: 0:01:38.
#   Batch 4,800  of  8,383.    Elapsed: 0:01:39.
#   Batch 4,840  of  8,383.    Elapsed: 0:01:40.
#   Batch 4,880  of  8,383.    Elapsed: 0:01:40.
#   Batch 4,920  of  8,383.    Elapsed: 0:01:41.
#   Batch 4,960  of  8,383.    Elapsed: 0:01:42.
#   Batch 5,000  of  8,383.    Elapsed: 0:01:43.
#   Batch 5,040  of  8,383.    Elapsed: 0:01:44.
#   Batch 5,080  of  8,383.    Elapsed: 0:01:45.
#   Batch 5,120  of  8,383.    Elapsed: 0:01:46.
#   Batch 5,160  of  8,383.    Elapsed: 0:01:46.
#   Batch 5,200  of  8,383.    Elapsed: 0:01:47.
#   Batch 5,240  of  8,383.    Elapsed: 0:01:48.
#   Batch 5,280  of  8,383.    Elapsed: 0:01:49.
#   Batch 5,320  of  8,383.    Elapsed: 0:01:50.
#   Batch 5,360  of  8,383.    Elapsed: 0:01:50.
#   Batch 5,400  of  8,383.    Elapsed: 0:01:51.
#   Batch 5,440  of  8,383.    Elapsed: 0:01:52.
#   Batch 5,480  of  8,383.    Elapsed: 0:01:53.
#   Batch 5,520  of  8,383.    Elapsed: 0:01:54.
#   Batch 5,560  of  8,383.    Elapsed: 0:01:54.
#   Batch 5,600  of  8,383.    Elapsed: 0:01:55.
#   Batch 5,640  of  8,383.    Elapsed: 0:01:56.
#   Batch 5,680  of  8,383.    Elapsed: 0:01:57.
#   Batch 5,720  of  8,383.    Elapsed: 0:01:58.
#   Batch 5,760  of  8,383.    Elapsed: 0:01:59.
#   Batch 5,800  of  8,383.    Elapsed: 0:02:00.
#   Batch 5,840  of  8,383.    Elapsed: 0:02:00.
#   Batch 5,880  of  8,383.    Elapsed: 0:02:01.
#   Batch 5,920  of  8,383.    Elapsed: 0:02:02.
#   Batch 5,960  of  8,383.    Elapsed: 0:02:03.
#   Batch 6,000  of  8,383.    Elapsed: 0:02:04.
#   Batch 6,040  of  8,383.    Elapsed: 0:02:04.
#   Batch 6,080  of  8,383.    Elapsed: 0:02:05.
#   Batch 6,120  of  8,383.    Elapsed: 0:02:06.
#   Batch 6,160  of  8,383.    Elapsed: 0:02:07.
#   Batch 6,200  of  8,383.    Elapsed: 0:02:08.
#   Batch 6,240  of  8,383.    Elapsed: 0:02:09.
#   Batch 6,280  of  8,383.    Elapsed: 0:02:09.
#   Batch 6,320  of  8,383.    Elapsed: 0:02:10.
#   Batch 6,360  of  8,383.    Elapsed: 0:02:11.
#   Batch 6,400  of  8,383.    Elapsed: 0:02:12.
#   Batch 6,440  of  8,383.    Elapsed: 0:02:13.
#   Batch 6,480  of  8,383.    Elapsed: 0:02:14.
#   Batch 6,520  of  8,383.    Elapsed: 0:02:14.
#   Batch 6,560  of  8,383.    Elapsed: 0:02:15.
#   Batch 6,600  of  8,383.    Elapsed: 0:02:16.
#   Batch 6,640  of  8,383.    Elapsed: 0:02:17.
#   Batch 6,680  of  8,383.    Elapsed: 0:02:18.
#   Batch 6,720  of  8,383.    Elapsed: 0:02:18.
#   Batch 6,760  of  8,383.    Elapsed: 0:02:19.
#   Batch 6,800  of  8,383.    Elapsed: 0:02:20.
#   Batch 6,840  of  8,383.    Elapsed: 0:02:21.
#   Batch 6,880  of  8,383.    Elapsed: 0:02:22.
#   Batch 6,920  of  8,383.    Elapsed: 0:02:23.
#   Batch 6,960  of  8,383.    Elapsed: 0:02:23.
#   Batch 7,000  of  8,383.    Elapsed: 0:02:24.
#   Batch 7,040  of  8,383.    Elapsed: 0:02:25.
#   Batch 7,080  of  8,383.    Elapsed: 0:02:26.
#   Batch 7,120  of  8,383.    Elapsed: 0:02:27.
#   Batch 7,160  of  8,383.    Elapsed: 0:02:28.
#   Batch 7,200  of  8,383.    Elapsed: 0:02:28.
#   Batch 7,240  of  8,383.    Elapsed: 0:02:29.
#   Batch 7,280  of  8,383.    Elapsed: 0:02:30.
#   Batch 7,320  of  8,383.    Elapsed: 0:02:31.
#   Batch 7,360  of  8,383.    Elapsed: 0:02:32.
#   Batch 7,400  of  8,383.    Elapsed: 0:02:32.
#   Batch 7,440  of  8,383.    Elapsed: 0:02:33.
#   Batch 7,480  of  8,383.    Elapsed: 0:02:34.
#   Batch 7,520  of  8,383.    Elapsed: 0:02:35.
#   Batch 7,560  of  8,383.    Elapsed: 0:02:36.
#   Batch 7,600  of  8,383.    Elapsed: 0:02:37.
#   Batch 7,640  of  8,383.    Elapsed: 0:02:37.
#   Batch 7,680  of  8,383.    Elapsed: 0:02:38.
#   Batch 7,720  of  8,383.    Elapsed: 0:02:39.
#   Batch 7,760  of  8,383.    Elapsed: 0:02:40.
#   Batch 7,800  of  8,383.    Elapsed: 0:02:41.
#   Batch 7,840  of  8,383.    Elapsed: 0:02:42.
#   Batch 7,880  of  8,383.    Elapsed: 0:02:42.
#   Batch 7,920  of  8,383.    Elapsed: 0:02:43.
#   Batch 7,960  of  8,383.    Elapsed: 0:02:44.
#   Batch 8,000  of  8,383.    Elapsed: 0:02:45.
#   Batch 8,040  of  8,383.    Elapsed: 0:02:46.
#   Batch 8,080  of  8,383.    Elapsed: 0:02:46.
#   Batch 8,120  of  8,383.    Elapsed: 0:02:47.
#   Batch 8,160  of  8,383.    Elapsed: 0:02:48.
#   Batch 8,200  of  8,383.    Elapsed: 0:02:49.
#   Batch 8,240  of  8,383.    Elapsed: 0:02:50.
#   Batch 8,280  of  8,383.    Elapsed: 0:02:51.
#   Batch 8,320  of  8,383.    Elapsed: 0:02:51.
#   Batch 8,360  of  8,383.    Elapsed: 0:02:52.
#
#   Average training loss: 0.39
#   Training epcoh took: 0:02:53
#
# Running Validation...
#   F1: 0.76
#   Validation Loss: 0.40
#   Validation took: 0:00:05
#
# ======== Epoch 3 / 4 ========
# Training...
#   Batch    40  of  8,383.    Elapsed: 0:00:01.
#   Batch    80  of  8,383.    Elapsed: 0:00:02.
#   Batch   120  of  8,383.    Elapsed: 0:00:02.
#   Batch   160  of  8,383.    Elapsed: 0:00:03.
#   Batch   200  of  8,383.    Elapsed: 0:00:04.
#   Batch   240  of  8,383.    Elapsed: 0:00:05.
#   Batch   280  of  8,383.    Elapsed: 0:00:06.
#   Batch   320  of  8,383.    Elapsed: 0:00:07.
#   Batch   360  of  8,383.    Elapsed: 0:00:08.
#   Batch   400  of  8,383.    Elapsed: 0:00:08.
#   Batch   440  of  8,383.    Elapsed: 0:00:09.
#   Batch   480  of  8,383.    Elapsed: 0:00:10.
#   Batch   520  of  8,383.    Elapsed: 0:00:11.
#   Batch   560  of  8,383.    Elapsed: 0:00:12.
#   Batch   600  of  8,383.    Elapsed: 0:00:13.
#   Batch   640  of  8,383.    Elapsed: 0:00:13.
#   Batch   680  of  8,383.    Elapsed: 0:00:14.
#   Batch   720  of  8,383.    Elapsed: 0:00:15.
#   Batch   760  of  8,383.    Elapsed: 0:00:16.
#   Batch   800  of  8,383.    Elapsed: 0:00:17.
#   Batch   840  of  8,383.    Elapsed: 0:00:17.
#   Batch   880  of  8,383.    Elapsed: 0:00:18.
#   Batch   920  of  8,383.    Elapsed: 0:00:19.
#   Batch   960  of  8,383.    Elapsed: 0:00:20.
#   Batch 1,000  of  8,383.    Elapsed: 0:00:21.
#   Batch 1,040  of  8,383.    Elapsed: 0:00:22.
#   Batch 1,080  of  8,383.    Elapsed: 0:00:23.
#   Batch 1,120  of  8,383.    Elapsed: 0:00:23.
#   Batch 1,160  of  8,383.    Elapsed: 0:00:24.
#   Batch 1,200  of  8,383.    Elapsed: 0:00:25.
#   Batch 1,240  of  8,383.    Elapsed: 0:00:26.
#   Batch 1,280  of  8,383.    Elapsed: 0:00:27.
#   Batch 1,320  of  8,383.    Elapsed: 0:00:27.
#   Batch 1,360  of  8,383.    Elapsed: 0:00:28.
#   Batch 1,400  of  8,383.    Elapsed: 0:00:29.
#   Batch 1,440  of  8,383.    Elapsed: 0:00:30.
#   Batch 1,480  of  8,383.    Elapsed: 0:00:31.
#   Batch 1,520  of  8,383.    Elapsed: 0:00:32.
#   Batch 1,560  of  8,383.    Elapsed: 0:00:33.
#   Batch 1,600  of  8,383.    Elapsed: 0:00:33.
#   Batch 1,640  of  8,383.    Elapsed: 0:00:34.
#   Batch 1,680  of  8,383.    Elapsed: 0:00:35.
#   Batch 1,720  of  8,383.    Elapsed: 0:00:36.
#   Batch 1,760  of  8,383.    Elapsed: 0:00:37.
#   Batch 1,800  of  8,383.    Elapsed: 0:00:38.
#   Batch 1,840  of  8,383.    Elapsed: 0:00:38.
#   Batch 1,880  of  8,383.    Elapsed: 0:00:39.
#   Batch 1,920  of  8,383.    Elapsed: 0:00:40.
#   Batch 1,960  of  8,383.    Elapsed: 0:00:41.
#   Batch 2,000  of  8,383.    Elapsed: 0:00:42.
#   Batch 2,040  of  8,383.    Elapsed: 0:00:42.
#   Batch 2,080  of  8,383.    Elapsed: 0:00:43.
#   Batch 2,120  of  8,383.    Elapsed: 0:00:44.
#   Batch 2,160  of  8,383.    Elapsed: 0:00:45.
#   Batch 2,200  of  8,383.    Elapsed: 0:00:46.
#   Batch 2,240  of  8,383.    Elapsed: 0:00:47.
#   Batch 2,280  of  8,383.    Elapsed: 0:00:48.
#   Batch 2,320  of  8,383.    Elapsed: 0:00:48.
#   Batch 2,360  of  8,383.    Elapsed: 0:00:49.
#   Batch 2,400  of  8,383.    Elapsed: 0:00:50.
#   Batch 2,440  of  8,383.    Elapsed: 0:00:51.
#   Batch 2,480  of  8,383.    Elapsed: 0:00:52.
#   Batch 2,520  of  8,383.    Elapsed: 0:00:52.
#   Batch 2,560  of  8,383.    Elapsed: 0:00:53.
#   Batch 2,600  of  8,383.    Elapsed: 0:00:54.
#   Batch 2,640  of  8,383.    Elapsed: 0:00:55.
#   Batch 2,680  of  8,383.    Elapsed: 0:00:56.
#   Batch 2,720  of  8,383.    Elapsed: 0:00:56.
#   Batch 2,760  of  8,383.    Elapsed: 0:00:57.
#   Batch 2,800  of  8,383.    Elapsed: 0:00:58.
#   Batch 2,840  of  8,383.    Elapsed: 0:00:59.
#   Batch 2,880  of  8,383.    Elapsed: 0:01:00.
#   Batch 2,920  of  8,383.    Elapsed: 0:01:01.
#   Batch 2,960  of  8,383.    Elapsed: 0:01:02.
#   Batch 3,000  of  8,383.    Elapsed: 0:01:02.
#   Batch 3,040  of  8,383.    Elapsed: 0:01:03.
#   Batch 3,080  of  8,383.    Elapsed: 0:01:04.
#   Batch 3,120  of  8,383.    Elapsed: 0:01:05.
#   Batch 3,160  of  8,383.    Elapsed: 0:01:06.
#   Batch 3,200  of  8,383.    Elapsed: 0:01:06.
#   Batch 3,240  of  8,383.    Elapsed: 0:01:07.
#   Batch 3,280  of  8,383.    Elapsed: 0:01:08.
#   Batch 3,320  of  8,383.    Elapsed: 0:01:09.
#   Batch 3,360  of  8,383.    Elapsed: 0:01:10.
#   Batch 3,400  of  8,383.    Elapsed: 0:01:11.
#   Batch 3,440  of  8,383.    Elapsed: 0:01:11.
#   Batch 3,480  of  8,383.    Elapsed: 0:01:12.
#   Batch 3,520  of  8,383.    Elapsed: 0:01:13.
#   Batch 3,560  of  8,383.    Elapsed: 0:01:14.
#   Batch 3,600  of  8,383.    Elapsed: 0:01:15.
#   Batch 3,640  of  8,383.    Elapsed: 0:01:16.
#   Batch 3,680  of  8,383.    Elapsed: 0:01:17.
#   Batch 3,720  of  8,383.    Elapsed: 0:01:17.
#   Batch 3,760  of  8,383.    Elapsed: 0:01:18.
#   Batch 3,800  of  8,383.    Elapsed: 0:01:19.
#   Batch 3,840  of  8,383.    Elapsed: 0:01:20.
#   Batch 3,880  of  8,383.    Elapsed: 0:01:21.
#   Batch 3,920  of  8,383.    Elapsed: 0:01:21.
#   Batch 3,960  of  8,383.    Elapsed: 0:01:22.
#   Batch 4,000  of  8,383.    Elapsed: 0:01:23.
#   Batch 4,040  of  8,383.    Elapsed: 0:01:24.
#   Batch 4,080  of  8,383.    Elapsed: 0:01:25.
#   Batch 4,120  of  8,383.    Elapsed: 0:01:25.
#   Batch 4,160  of  8,383.    Elapsed: 0:01:26.
#   Batch 4,200  of  8,383.    Elapsed: 0:01:27.
#   Batch 4,240  of  8,383.    Elapsed: 0:01:28.
#   Batch 4,280  of  8,383.    Elapsed: 0:01:29.
#   Batch 4,320  of  8,383.    Elapsed: 0:01:30.
#   Batch 4,360  of  8,383.    Elapsed: 0:01:31.
#   Batch 4,400  of  8,383.    Elapsed: 0:01:31.
#   Batch 4,440  of  8,383.    Elapsed: 0:01:32.
#   Batch 4,480  of  8,383.    Elapsed: 0:01:33.
#   Batch 4,520  of  8,383.    Elapsed: 0:01:34.
#   Batch 4,560  of  8,383.    Elapsed: 0:01:35.
#   Batch 4,600  of  8,383.    Elapsed: 0:01:35.
#   Batch 4,640  of  8,383.    Elapsed: 0:01:36.
#   Batch 4,680  of  8,383.    Elapsed: 0:01:37.
#   Batch 4,720  of  8,383.    Elapsed: 0:01:38.
#   Batch 4,760  of  8,383.    Elapsed: 0:01:39.
#   Batch 4,800  of  8,383.    Elapsed: 0:01:40.
#   Batch 4,840  of  8,383.    Elapsed: 0:01:40.
#   Batch 4,880  of  8,383.    Elapsed: 0:01:41.
#   Batch 4,920  of  8,383.    Elapsed: 0:01:42.
#   Batch 4,960  of  8,383.    Elapsed: 0:01:43.
#   Batch 5,000  of  8,383.    Elapsed: 0:01:44.
#   Batch 5,040  of  8,383.    Elapsed: 0:01:45.
#   Batch 5,080  of  8,383.    Elapsed: 0:01:45.
#   Batch 5,120  of  8,383.    Elapsed: 0:01:46.
#   Batch 5,160  of  8,383.    Elapsed: 0:01:47.
#   Batch 5,200  of  8,383.    Elapsed: 0:01:48.
#   Batch 5,240  of  8,383.    Elapsed: 0:01:49.
#   Batch 5,280  of  8,383.    Elapsed: 0:01:49.
#   Batch 5,320  of  8,383.    Elapsed: 0:01:50.
#   Batch 5,360  of  8,383.    Elapsed: 0:01:51.
#   Batch 5,400  of  8,383.    Elapsed: 0:01:52.
#   Batch 5,440  of  8,383.    Elapsed: 0:01:53.
#   Batch 5,480  of  8,383.    Elapsed: 0:01:54.
#   Batch 5,520  of  8,383.    Elapsed: 0:01:55.
#   Batch 5,560  of  8,383.    Elapsed: 0:01:55.
#   Batch 5,600  of  8,383.    Elapsed: 0:01:56.
#   Batch 5,640  of  8,383.    Elapsed: 0:01:57.
#   Batch 5,680  of  8,383.    Elapsed: 0:01:58.
#   Batch 5,720  of  8,383.    Elapsed: 0:01:59.
#   Batch 5,760  of  8,383.    Elapsed: 0:01:59.
#   Batch 5,800  of  8,383.    Elapsed: 0:02:00.
#   Batch 5,840  of  8,383.    Elapsed: 0:02:01.
#   Batch 5,880  of  8,383.    Elapsed: 0:02:02.
#   Batch 5,920  of  8,383.    Elapsed: 0:02:03.
#   Batch 5,960  of  8,383.    Elapsed: 0:02:03.
#   Batch 6,000  of  8,383.    Elapsed: 0:02:04.
#   Batch 6,040  of  8,383.    Elapsed: 0:02:05.
#   Batch 6,080  of  8,383.    Elapsed: 0:02:06.
#   Batch 6,120  of  8,383.    Elapsed: 0:02:07.
#   Batch 6,160  of  8,383.    Elapsed: 0:02:08.
#   Batch 6,200  of  8,383.    Elapsed: 0:02:09.
#   Batch 6,240  of  8,383.    Elapsed: 0:02:09.
#   Batch 6,280  of  8,383.    Elapsed: 0:02:10.
#   Batch 6,320  of  8,383.    Elapsed: 0:02:11.
#   Batch 6,360  of  8,383.    Elapsed: 0:02:12.
#   Batch 6,400  of  8,383.    Elapsed: 0:02:13.
#   Batch 6,440  of  8,383.    Elapsed: 0:02:13.
#   Batch 6,480  of  8,383.    Elapsed: 0:02:14.
#   Batch 6,520  of  8,383.    Elapsed: 0:02:15.
#   Batch 6,560  of  8,383.    Elapsed: 0:02:16.
#   Batch 6,600  of  8,383.    Elapsed: 0:02:17.
#   Batch 6,640  of  8,383.    Elapsed: 0:02:17.
#   Batch 6,680  of  8,383.    Elapsed: 0:02:18.
#   Batch 6,720  of  8,383.    Elapsed: 0:02:19.
#   Batch 6,760  of  8,383.    Elapsed: 0:02:20.
#   Batch 6,800  of  8,383.    Elapsed: 0:02:21.
#   Batch 6,840  of  8,383.    Elapsed: 0:02:22.
#   Batch 6,880  of  8,383.    Elapsed: 0:02:23.
#   Batch 6,920  of  8,383.    Elapsed: 0:02:23.
#   Batch 6,960  of  8,383.    Elapsed: 0:02:24.
#   Batch 7,000  of  8,383.    Elapsed: 0:02:25.
#   Batch 7,040  of  8,383.    Elapsed: 0:02:26.
#   Batch 7,080  of  8,383.    Elapsed: 0:02:27.
#   Batch 7,120  of  8,383.    Elapsed: 0:02:27.
#   Batch 7,160  of  8,383.    Elapsed: 0:02:28.
#   Batch 7,200  of  8,383.    Elapsed: 0:02:29.
#   Batch 7,240  of  8,383.    Elapsed: 0:02:30.
#   Batch 7,280  of  8,383.    Elapsed: 0:02:31.
#   Batch 7,320  of  8,383.    Elapsed: 0:02:31.
#   Batch 7,360  of  8,383.    Elapsed: 0:02:32.
#   Batch 7,400  of  8,383.    Elapsed: 0:02:33.
#   Batch 7,440  of  8,383.    Elapsed: 0:02:34.
#   Batch 7,480  of  8,383.    Elapsed: 0:02:35.
#   Batch 7,520  of  8,383.    Elapsed: 0:02:36.
#   Batch 7,560  of  8,383.    Elapsed: 0:02:37.
#   Batch 7,600  of  8,383.    Elapsed: 0:02:37.
#   Batch 7,640  of  8,383.    Elapsed: 0:02:38.
#   Batch 7,680  of  8,383.    Elapsed: 0:02:39.
#   Batch 7,720  of  8,383.    Elapsed: 0:02:40.
#   Batch 7,760  of  8,383.    Elapsed: 0:02:41.
#   Batch 7,800  of  8,383.    Elapsed: 0:02:41.
#   Batch 7,840  of  8,383.    Elapsed: 0:02:42.
#   Batch 7,880  of  8,383.    Elapsed: 0:02:43.
#   Batch 7,920  of  8,383.    Elapsed: 0:02:44.
#   Batch 7,960  of  8,383.    Elapsed: 0:02:45.
#   Batch 8,000  of  8,383.    Elapsed: 0:02:45.
#   Batch 8,040  of  8,383.    Elapsed: 0:02:46.
#   Batch 8,080  of  8,383.    Elapsed: 0:02:47.
#   Batch 8,120  of  8,383.    Elapsed: 0:02:48.
#   Batch 8,160  of  8,383.    Elapsed: 0:02:49.
#   Batch 8,200  of  8,383.    Elapsed: 0:02:50.
#   Batch 8,240  of  8,383.    Elapsed: 0:02:51.
#   Batch 8,280  of  8,383.    Elapsed: 0:02:51.
#   Batch 8,320  of  8,383.    Elapsed: 0:02:52.
#   Batch 8,360  of  8,383.    Elapsed: 0:02:53.
#
#   Average training loss: 0.34
#   Training epcoh took: 0:02:53
#
# Running Validation...
#   F1: 0.77
#   Validation Loss: 0.40
#   Validation took: 0:00:05
#
# ======== Epoch 4 / 4 ========
# Training...
#   Batch    40  of  8,383.    Elapsed: 0:00:01.
#   Batch    80  of  8,383.    Elapsed: 0:00:02.
#   Batch   120  of  8,383.    Elapsed: 0:00:03.
#   Batch   160  of  8,383.    Elapsed: 0:00:03.
#   Batch   200  of  8,383.    Elapsed: 0:00:04.
#   Batch   240  of  8,383.    Elapsed: 0:00:05.
#   Batch   280  of  8,383.    Elapsed: 0:00:06.
#   Batch   320  of  8,383.    Elapsed: 0:00:07.
#   Batch   360  of  8,383.    Elapsed: 0:00:08.
#   Batch   400  of  8,383.    Elapsed: 0:00:08.
#   Batch   440  of  8,383.    Elapsed: 0:00:09.
#   Batch   480  of  8,383.    Elapsed: 0:00:10.
#   Batch   520  of  8,383.    Elapsed: 0:00:11.
#   Batch   560  of  8,383.    Elapsed: 0:00:12.
#   Batch   600  of  8,383.    Elapsed: 0:00:12.
#   Batch   640  of  8,383.    Elapsed: 0:00:13.
#   Batch   680  of  8,383.    Elapsed: 0:00:14.
#   Batch   720  of  8,383.    Elapsed: 0:00:15.
#   Batch   760  of  8,383.    Elapsed: 0:00:16.
#   Batch   800  of  8,383.    Elapsed: 0:00:17.
#   Batch   840  of  8,383.    Elapsed: 0:00:17.
#   Batch   880  of  8,383.    Elapsed: 0:00:18.
#   Batch   920  of  8,383.    Elapsed: 0:00:19.
#   Batch   960  of  8,383.    Elapsed: 0:00:20.
#   Batch 1,000  of  8,383.    Elapsed: 0:00:21.
#   Batch 1,040  of  8,383.    Elapsed: 0:00:22.
#   Batch 1,080  of  8,383.    Elapsed: 0:00:22.
#   Batch 1,120  of  8,383.    Elapsed: 0:00:23.
#   Batch 1,160  of  8,383.    Elapsed: 0:00:24.
#   Batch 1,200  of  8,383.    Elapsed: 0:00:25.
#   Batch 1,240  of  8,383.    Elapsed: 0:00:26.
#   Batch 1,280  of  8,383.    Elapsed: 0:00:26.
#   Batch 1,320  of  8,383.    Elapsed: 0:00:27.
#   Batch 1,360  of  8,383.    Elapsed: 0:00:28.
#   Batch 1,400  of  8,383.    Elapsed: 0:00:29.
#   Batch 1,440  of  8,383.    Elapsed: 0:00:30.
#   Batch 1,480  of  8,383.    Elapsed: 0:00:31.
#   Batch 1,520  of  8,383.    Elapsed: 0:00:31.
#   Batch 1,560  of  8,383.    Elapsed: 0:00:32.
#   Batch 1,600  of  8,383.    Elapsed: 0:00:33.
#   Batch 1,640  of  8,383.    Elapsed: 0:00:34.
#   Batch 1,680  of  8,383.    Elapsed: 0:00:35.
#   Batch 1,720  of  8,383.    Elapsed: 0:00:35.
#   Batch 1,760  of  8,383.    Elapsed: 0:00:36.
#   Batch 1,800  of  8,383.    Elapsed: 0:00:37.
#   Batch 1,840  of  8,383.    Elapsed: 0:00:38.
#   Batch 1,880  of  8,383.    Elapsed: 0:00:39.
#   Batch 1,920  of  8,383.    Elapsed: 0:00:40.
#   Batch 1,960  of  8,383.    Elapsed: 0:00:40.
#   Batch 2,000  of  8,383.    Elapsed: 0:00:41.
#   Batch 2,040  of  8,383.    Elapsed: 0:00:42.
#   Batch 2,080  of  8,383.    Elapsed: 0:00:43.
#   Batch 2,120  of  8,383.    Elapsed: 0:00:44.
#   Batch 2,160  of  8,383.    Elapsed: 0:00:45.
#   Batch 2,200  of  8,383.    Elapsed: 0:00:45.
#   Batch 2,240  of  8,383.    Elapsed: 0:00:46.
#   Batch 2,280  of  8,383.    Elapsed: 0:00:47.
#   Batch 2,320  of  8,383.    Elapsed: 0:00:48.
#   Batch 2,360  of  8,383.    Elapsed: 0:00:49.
#   Batch 2,400  of  8,383.    Elapsed: 0:00:49.
#   Batch 2,440  of  8,383.    Elapsed: 0:00:50.
#   Batch 2,480  of  8,383.    Elapsed: 0:00:51.
#   Batch 2,520  of  8,383.    Elapsed: 0:00:52.
#   Batch 2,560  of  8,383.    Elapsed: 0:00:53.
#   Batch 2,600  of  8,383.    Elapsed: 0:00:53.
#   Batch 2,640  of  8,383.    Elapsed: 0:00:54.
#   Batch 2,680  of  8,383.    Elapsed: 0:00:55.
#   Batch 2,720  of  8,383.    Elapsed: 0:00:56.
#   Batch 2,760  of  8,383.    Elapsed: 0:00:57.
#   Batch 2,800  of  8,383.    Elapsed: 0:00:58.
#   Batch 2,840  of  8,383.    Elapsed: 0:00:59.
#   Batch 2,880  of  8,383.    Elapsed: 0:00:59.
#   Batch 2,920  of  8,383.    Elapsed: 0:01:00.
#   Batch 2,960  of  8,383.    Elapsed: 0:01:01.
#   Batch 3,000  of  8,383.    Elapsed: 0:01:02.
#   Batch 3,040  of  8,383.    Elapsed: 0:01:03.
#   Batch 3,080  of  8,383.    Elapsed: 0:01:03.
#   Batch 3,120  of  8,383.    Elapsed: 0:01:04.
#   Batch 3,160  of  8,383.    Elapsed: 0:01:05.
#   Batch 3,200  of  8,383.    Elapsed: 0:01:06.
#   Batch 3,240  of  8,383.    Elapsed: 0:01:07.
#   Batch 3,280  of  8,383.    Elapsed: 0:01:07.
#   Batch 3,320  of  8,383.    Elapsed: 0:01:08.
#   Batch 3,360  of  8,383.    Elapsed: 0:01:09.
#   Batch 3,400  of  8,383.    Elapsed: 0:01:10.
#   Batch 3,440  of  8,383.    Elapsed: 0:01:11.
#   Batch 3,480  of  8,383.    Elapsed: 0:01:12.
#   Batch 3,520  of  8,383.    Elapsed: 0:01:13.
#   Batch 3,560  of  8,383.    Elapsed: 0:01:13.
#   Batch 3,600  of  8,383.    Elapsed: 0:01:14.
#   Batch 3,640  of  8,383.    Elapsed: 0:01:15.
#   Batch 3,680  of  8,383.    Elapsed: 0:01:16.
#   Batch 3,720  of  8,383.    Elapsed: 0:01:17.
#   Batch 3,760  of  8,383.    Elapsed: 0:01:17.
#   Batch 3,800  of  8,383.    Elapsed: 0:01:18.
#   Batch 3,840  of  8,383.    Elapsed: 0:01:19.
#   Batch 3,880  of  8,383.    Elapsed: 0:01:20.
#   Batch 3,920  of  8,383.    Elapsed: 0:01:21.
#   Batch 3,960  of  8,383.    Elapsed: 0:01:22.
#   Batch 4,000  of  8,383.    Elapsed: 0:01:22.
#   Batch 4,040  of  8,383.    Elapsed: 0:01:23.
#   Batch 4,080  of  8,383.    Elapsed: 0:01:24.
#   Batch 4,120  of  8,383.    Elapsed: 0:01:25.
#   Batch 4,160  of  8,383.    Elapsed: 0:01:26.
#   Batch 4,200  of  8,383.    Elapsed: 0:01:27.
#   Batch 4,240  of  8,383.    Elapsed: 0:01:27.
#   Batch 4,280  of  8,383.    Elapsed: 0:01:28.
#   Batch 4,320  of  8,383.    Elapsed: 0:01:29.
#   Batch 4,360  of  8,383.    Elapsed: 0:01:30.
#   Batch 4,400  of  8,383.    Elapsed: 0:01:31.
#   Batch 4,440  of  8,383.    Elapsed: 0:01:31.
#   Batch 4,480  of  8,383.    Elapsed: 0:01:32.
#   Batch 4,520  of  8,383.    Elapsed: 0:01:33.
#   Batch 4,560  of  8,383.    Elapsed: 0:01:34.
#   Batch 4,600  of  8,383.    Elapsed: 0:01:35.
#   Batch 4,640  of  8,383.    Elapsed: 0:01:36.
#   Batch 4,680  of  8,383.    Elapsed: 0:01:36.
#   Batch 4,720  of  8,383.    Elapsed: 0:01:37.
#   Batch 4,760  of  8,383.    Elapsed: 0:01:38.
#   Batch 4,800  of  8,383.    Elapsed: 0:01:39.
#   Batch 4,840  of  8,383.    Elapsed: 0:01:40.
#   Batch 4,880  of  8,383.    Elapsed: 0:01:41.
#   Batch 4,920  of  8,383.    Elapsed: 0:01:41.
#   Batch 4,960  of  8,383.    Elapsed: 0:01:42.
#   Batch 5,000  of  8,383.    Elapsed: 0:01:43.
#   Batch 5,040  of  8,383.    Elapsed: 0:01:44.
#   Batch 5,080  of  8,383.    Elapsed: 0:01:45.
#   Batch 5,120  of  8,383.    Elapsed: 0:01:45.
#   Batch 5,160  of  8,383.    Elapsed: 0:01:46.
#   Batch 5,200  of  8,383.    Elapsed: 0:01:47.
#   Batch 5,240  of  8,383.    Elapsed: 0:01:48.
#   Batch 5,280  of  8,383.    Elapsed: 0:01:49.
#   Batch 5,320  of  8,383.    Elapsed: 0:01:50.
#   Batch 5,360  of  8,383.    Elapsed: 0:01:50.
#   Batch 5,400  of  8,383.    Elapsed: 0:01:51.
#   Batch 5,440  of  8,383.    Elapsed: 0:01:52.
#   Batch 5,480  of  8,383.    Elapsed: 0:01:53.
#   Batch 5,520  of  8,383.    Elapsed: 0:01:54.
#   Batch 5,560  of  8,383.    Elapsed: 0:01:55.
#   Batch 5,600  of  8,383.    Elapsed: 0:01:55.
#   Batch 5,640  of  8,383.    Elapsed: 0:01:56.
#   Batch 5,680  of  8,383.    Elapsed: 0:01:57.
#   Batch 5,720  of  8,383.    Elapsed: 0:01:58.
#   Batch 5,760  of  8,383.    Elapsed: 0:01:59.
#   Batch 5,800  of  8,383.    Elapsed: 0:01:59.
#   Batch 5,840  of  8,383.    Elapsed: 0:02:00.
#   Batch 5,880  of  8,383.    Elapsed: 0:02:01.
#   Batch 5,920  of  8,383.    Elapsed: 0:02:02.
#   Batch 5,960  of  8,383.    Elapsed: 0:02:03.
#   Batch 6,000  of  8,383.    Elapsed: 0:02:03.
#   Batch 6,040  of  8,383.    Elapsed: 0:02:04.
#   Batch 6,080  of  8,383.    Elapsed: 0:02:05.
#   Batch 6,120  of  8,383.    Elapsed: 0:02:06.
#   Batch 6,160  of  8,383.    Elapsed: 0:02:07.
#   Batch 6,200  of  8,383.    Elapsed: 0:02:08.
#   Batch 6,240  of  8,383.    Elapsed: 0:02:09.
#   Batch 6,280  of  8,383.    Elapsed: 0:02:09.
#   Batch 6,320  of  8,383.    Elapsed: 0:02:10.
#   Batch 6,360  of  8,383.    Elapsed: 0:02:11.
#   Batch 6,400  of  8,383.    Elapsed: 0:02:12.
#   Batch 6,440  of  8,383.    Elapsed: 0:02:13.
#   Batch 6,480  of  8,383.    Elapsed: 0:02:13.
#   Batch 6,520  of  8,383.    Elapsed: 0:02:14.
#   Batch 6,560  of  8,383.    Elapsed: 0:02:15.
#   Batch 6,600  of  8,383.    Elapsed: 0:02:16.
#   Batch 6,640  of  8,383.    Elapsed: 0:02:17.
#   Batch 6,680  of  8,383.    Elapsed: 0:02:18.
#   Batch 6,720  of  8,383.    Elapsed: 0:02:18.
#   Batch 6,760  of  8,383.    Elapsed: 0:02:19.
#   Batch 6,800  of  8,383.    Elapsed: 0:02:20.
#   Batch 6,840  of  8,383.    Elapsed: 0:02:21.
#   Batch 6,880  of  8,383.    Elapsed: 0:02:22.
#   Batch 6,920  of  8,383.    Elapsed: 0:02:22.
#   Batch 6,960  of  8,383.    Elapsed: 0:02:23.
#   Batch 7,000  of  8,383.    Elapsed: 0:02:24.
#   Batch 7,040  of  8,383.    Elapsed: 0:02:25.
#   Batch 7,080  of  8,383.    Elapsed: 0:02:26.
#   Batch 7,120  of  8,383.    Elapsed: 0:02:26.
#   Batch 7,160  of  8,383.    Elapsed: 0:02:27.
#   Batch 7,200  of  8,383.    Elapsed: 0:02:28.
#   Batch 7,240  of  8,383.    Elapsed: 0:02:29.
#   Batch 7,280  of  8,383.    Elapsed: 0:02:30.
#   Batch 7,320  of  8,383.    Elapsed: 0:02:31.
#   Batch 7,360  of  8,383.    Elapsed: 0:02:32.
#   Batch 7,400  of  8,383.    Elapsed: 0:02:32.
#   Batch 7,440  of  8,383.    Elapsed: 0:02:33.
#   Batch 7,480  of  8,383.    Elapsed: 0:02:34.
#   Batch 7,520  of  8,383.    Elapsed: 0:02:35.
#   Batch 7,560  of  8,383.    Elapsed: 0:02:36.
#   Batch 7,600  of  8,383.    Elapsed: 0:02:36.
#   Batch 7,640  of  8,383.    Elapsed: 0:02:37.
#   Batch 7,680  of  8,383.    Elapsed: 0:02:38.
#   Batch 7,720  of  8,383.    Elapsed: 0:02:39.
#   Batch 7,760  of  8,383.    Elapsed: 0:02:40.
#   Batch 7,800  of  8,383.    Elapsed: 0:02:40.
#   Batch 7,840  of  8,383.    Elapsed: 0:02:41.
#   Batch 7,880  of  8,383.    Elapsed: 0:02:42.
#   Batch 7,920  of  8,383.    Elapsed: 0:02:43.
#   Batch 7,960  of  8,383.    Elapsed: 0:02:44.
#   Batch 8,000  of  8,383.    Elapsed: 0:02:45.
#   Batch 8,040  of  8,383.    Elapsed: 0:02:46.
#   Batch 8,080  of  8,383.    Elapsed: 0:02:46.
#   Batch 8,120  of  8,383.    Elapsed: 0:02:47.
#   Batch 8,160  of  8,383.    Elapsed: 0:02:48.
#   Batch 8,200  of  8,383.    Elapsed: 0:02:49.
#   Batch 8,240  of  8,383.    Elapsed: 0:02:50.
#   Batch 8,280  of  8,383.    Elapsed: 0:02:50.
#   Batch 8,320  of  8,383.    Elapsed: 0:02:51.
#   Batch 8,360  of  8,383.    Elapsed: 0:02:52.
#
#   Average training loss: 0.32
#   Training epcoh took: 0:02:53
#
# Running Validation...
#   F1: 0.77
#   Validation Loss: 0.40
#   Validation took: 0:00:05
#
# Training complete!
# Total training took 0:11:51 (h:mm:ss)

# %% [markdown]
# Посмотрим на саммари обучающего процесса!

# %%
# Display floats with two decimal places.
pd.set_option("display.max_columns", 100)

# Create a DataFrame from our training statistics.
df_stats = pd.DataFrame(data=training_stats)

# Use the 'epoch' as the row index.
df_stats = df_stats.set_index('epoch')

# Display the table.
df_stats
# Out:
#        Training Loss  Valid. Loss  Valid. F1. Training Time Validation Time
# epoch
# 1           0.554434     0.426209    0.745252       0:02:52         0:00:05
# 2           0.394008     0.397610    0.759853       0:02:53         0:00:05
# 3           0.344973     0.396672    0.765504       0:02:53         0:00:05
# 4           0.317761     0.397387    0.767617       0:02:53         0:00:05

# %% [markdown]
# Обратите внимание, что loss на обучении непрерывно падает, а на валидации начинает возрастать. Это говорит о том, что модель переобучается.
#
# Loss на валидации - более надежный способ, чем F1, так как F1 не зависит от типа ошибки и уверенности классификатора в ответе.

# %%
# Use plot styling from seaborn.
sns.set(style='darkgrid')

# Increase the plot size and font size.
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)

# Plot the learning curve.
plt.plot(df_stats['Training Loss'], 'b-o', label="Training")
plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation")

# Label the plot.
plt.title("Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.xticks([1, 2, 3, 4])

plt.show()

# %% [markdown]
# # 5. Performance On Test Set

# %% [markdown]
# Качество на отложенной выборке. Для оценки качества зафайнтьюненой модели оценим качество на тесте с использованием F1_score.

# %% [markdown]
# ### 5.1. Подготовка данных

# %% [markdown]
# Применим к тестовым данным те же шаги предобработки данных, которые мы применяли для обучающей и валидационной выборкок.

# %%
df = pd.read_csv('drive/MyDrive/test_data.csv')

# %%
# Report the number of sentences.
print('Number of test sentences: {:,}\n'.format(df.shape[0]))
# Out:
# Number of test sentences: 52,598

# %%
df.groupby(label_column).count()
# Out:
#                                       review  review_snippet
# category
# Административная деятельность           3753            3753
# Внеучебная деятельность                 2388            2388
# Инфраструктура                          6878            6878
# Лояльность к ВУЗу                       7539            7539
# Образовательная деятельность + НИР     29279           29279
# Финансово-экономическая деятельность    2761            2761

# %%
df[label_column]
# Out:
# 0                              Инфраструктура
# 1        Финансово-экономическая деятельность
# 2                           Лояльность к ВУЗу
# 3          Образовательная деятельность + НИР
# 4                              Инфраструктура
#                          ...
# 52593                          Инфраструктура
# 52594      Образовательная деятельность + НИР
# 52595      Образовательная деятельность + НИР
# 52596                          Инфраструктура
# 52597                       Лояльность к ВУЗу
# Name: category, Length: 52598, dtype: object

# %%
# Create sentence and label lists
texts = df[text_column].astype(str).values
labels = encoder.fit_transform(df[label_column])

# %%
texts[:2]
# Out:
# array(['Огромная территория,со своим спорткомплексом, что безумно удобно,прекрасные парки,прям как в санатории, а учиться как здорово в такой красоте!))',
#        'Студенту некуда деться (разве что перевестись в другой ВУЗ), и он решает остаться здесь, платит постоянно растущие суммы за семестр (но это мелочи'],
#       dtype=object)

# %%
labels
# Out:
# array([2, 5, 3, ..., 4, 2, 3])

# %%
# Tokenize all of the texts and map the tokens to thier word IDs.
input_ids, attention_masks, labels = preparing_text_and_labels(texts, labels, max_length, truncation=True) #Truncation for evoiding long cases

# %%
# Create the DataLoader.
prediction_data = TensorDataset(input_ids, attention_masks, labels)
prediction_sampler = SequentialSampler(prediction_data)
prediction_dataloader = DataLoader(prediction_data, sampler=prediction_sampler, batch_size=batch_size)

# %% [markdown]
# ## 5.2. Оценка на тесте

# %% [markdown]
# После того, как мы подготовили тестовые данные, сгенерируем предсказания с использованием дообученной модели.

# %%
# Prediction on test set
def get_predictions(model, prediction_dataloader):
  print('Predicting labels for {:,} test texts...'.format(len(input_ids)))
  # Put model in evaluation mode
  model.eval()

  # Tracking variables
  predictions , true_labels = [], []

  # Predict
  for batch in prediction_dataloader:
    # Add batch to GPU
    batch = tuple(t.to(device) for t in batch)

    # Unpack the inputs from our dataloader
    b_input_ids, b_input_mask, b_labels = batch

    with torch.no_grad():
        # Forward pass, calculate logit predictions
        outputs = model(b_input_ids, token_type_ids=None,
                        attention_mask=b_input_mask)

    logits = outputs[0]

    # Move logits and labels to CPU
    logits = logits.detach().cpu().numpy()
    label_ids = b_labels.to('cpu').numpy()

    # Store predictions and true labels
    predictions.append(logits)
    true_labels.append(label_ids)

  print()
  print('DONE.')
  return predictions, true_labels

# %%
predictions, true_labels = get_predictions(model, prediction_dataloader)
# Out:
# Predicting labels for 52,598 test texts...
#
# DONE.

# %% [markdown]
# В качестве метрики возьмем F1.

# %%
f1_set = []

# Evaluate each test batch using Matthew's correlation coefficient
print('Calculating F1 Score for each batch...')

# For each input batch...
for i in range(len(true_labels)):

  pred_labels_i = np.argmax(predictions[i], axis=1).flatten()

  # Calculate and store the coef for this batch.
  f1 = f1_score(true_labels[i], pred_labels_i, average='macro')
  f1_set.append(f1)
# Out:
# Calculating F1 Score for each batch...

# %% [markdown]
# Финальный скор считается по всему датасету, дополнительно посмотрим на скоры на отдельных батчах.

# %%
# Create a barplot showing the F1 score for each batch of test samples.
ax = sns.barplot(x=list(range(len(f1_set))), y=f1_set, errorbar=None)

plt.title('F1 Score per Batch')
plt.ylabel('F1')
plt.xlabel('Batches')

plt.show()

# %% [markdown]
# Объединим результаты и получим общий скор.

# %%
# Combine the results across all batches.
flat_predictions = np.concatenate(predictions, axis=0)

# For each sample, pick the label (0 or 1) with the higher score.
flat_predictions = np.argmax(flat_predictions, axis=1).flatten()

# Combine the correct labels for each batch into a single list.
flat_true_labels = np.concatenate(true_labels, axis=0)

# Calculate the F1
f1 = f1_score(flat_true_labels, flat_predictions, average='macro')
accuracy = accuracy_score(flat_true_labels, flat_predictions)
precision = precision_score(flat_true_labels, flat_predictions, average='macro')
recall = recall_score(flat_true_labels, flat_predictions, average='macro')


print('Total Accuracy: %.3f' % accuracy)
print('Total Precision: %.3f' % precision)
print('Total Recall: %.3f' % recall)
print('Total F1: %.3f' % f1)
# Out:
# Total Accuracy: 0.862
# Total Precision: 0.816
# Total Recall: 0.804
# Total F1: 0.810

# %% [markdown]
# **Успех!** Спустя небольшое количество времени мы получили хорошую модель с качеством выше чем у моделей, обученных с нуля.

# %% [markdown]
# # Заключение

# %% [markdown]
# Используя предобученную модель cointegrated/rubert-tiny2 с помощью простого файн тюнинга удается добиться лучшего качества среди всех моделей. А также модель довольно быстро обучается, что позволит в дальнейшем только улучшать её.

# %% [markdown]
# ##  Сохранение модели
#
# Код ниже позволяет сохранить дообученную модель и соотвествующий ей токенайзер на диск.
#
# Так как код выполнялся на GPU Google Colab.

# %%
output_dir = './model_save/'

# Create output directory if needed
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

print("Saving model to %s" % output_dir)

# Save a trained model, configuration and tokenizer using `save_pretrained()`.
# They can then be reloaded using `from_pretrained()`
model_to_save = model.module if hasattr(model, 'module') else model
model_to_save.save_pretrained(output_dir)
tokenizer.save_pretrained(output_dir)

# Good practice: save your training arguments together with the trained model
# torch.save(args, os.path.join(output_dir, 'training_args.bin'))
# Out:
# Saving model to ./model_save/
# ('./model_save/tokenizer_config.json',
#  './model_save/special_tokens_map.json',
#  './model_save/vocab.txt',
#  './model_save/added_tokens.json')

# %% [markdown]
# Посмотрим размеры файлов.

# %%
# !ls -l --block-size=K ./model_save/
# Out:
# total 115120K
# -rw-r--r-- 1 root root      1K Sep  2 14:50 config.json
# -rw-r--r-- 1 root root 114052K Sep  2 14:50 model.safetensors
# -rw-r--r-- 1 root root      1K Sep  2 14:50 special_tokens_map.json
# -rw-r--r-- 1 root root      2K Sep  2 14:50 tokenizer_config.json
# -rw-r--r-- 1 root root   1056K Sep  2 14:50 vocab.txt

# %%
# !ls -l --block-size=M ./model_save/model.safetensors
# Out:
# -rw-r--r-- 1 root root 112M Sep  2 14:50 ./model_save/model.safetensors

# %% [markdown]
# Файл весит всего 112 мб

# %% [markdown]
# Код ниже позволяет сохранить модель из колаба на Google Disk.

# %%
# Copy the model files to a directory in your Google Drive.
# !cp -r ./model_save/ "./drive/myfile_andreykasha"
# Out:
# cp: cannot create directory './drive/myfile_andreykasha': Operation not supported

# %% [markdown]
# Код ниже позволяет загрузить сохраненную модель.

# %%
# Load a trained model and vocabulary that you have fine-tuned
model = BertForSequenceClassification.from_pretrained(output_dir)
tokenizer = BertTokenizer.from_pretrained(output_dir)

# Copy the model to the GPU.
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(83828, 312, padding_idx=0)
#       (position_embeddings): Embedding(2048, 312)
#       (token_type_embeddings): Embedding(2, 312)
#       (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-2): 3 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=312, out_features=312, bias=True)
#               (key): Linear(in_features=312, out_features=312, bias=True)
#               (value): Linear(in_features=312, out_features=312, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=312, out_features=312, bias=True)
#               (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=312, out_features=600, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=600, out_features=312, bias=True)
#             (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=312, out_features=312, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=312, out_features=6, bias=True)
# )
